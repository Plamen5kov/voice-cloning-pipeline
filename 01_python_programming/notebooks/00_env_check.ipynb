# %%
# Environment Setup

This notebook will help you verify your environment and dependencies for the voice cloning pipeline.

## Steps
1. Check Python version
2. Check GPU availability
3. Check key library imports

---

You can run each cell to verify your setup. If you see any errors, please fix them before proceeding to the next steps.
